# %% [markdown]
# # preprocessing

# %%
import MeCab, re, tqdm, json, glob
from collections import Counter
import os, random, re, csv, json, datetime
import mysql.connector
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
# lemmatize
tagger = MeCab.Tagger()
def lemma(text:str) -> list:
    return [x.split(',')[6] for x in tagger.parse(text).split('\n')[:-2]]

def tokenize(text:str) -> list:
    """
    tokenize sentence into list of tokens with linguistic features
    0:surface form, 1:pos, 2:pos2, 3:pos3, 4:pos4, 5:conjugation type, 6:conjugation form, 7:lemma, 8:phono, 9:phone

    >>> tokenize('大きい家は走りたくなるな')
    [['大きい', '形容詞', '自立', '*', '*', '形容詞・イ段', '基本形', '大きい', 'オオキイ', 'オーキイ'],
    ['家', '名詞', '一般', '*', '*', '*', '*', '家', 'イエ', 'イエ'],
    ['は', '助詞', '係助詞', '*', '*', '*', '*', 'は', 'ハ', 'ワ'],
    ['走り', '動詞', '自立', '*', '*', '五段・ラ行', '連用形', '走る', 'ハシリ', 'ハシリ'],
    ['たく', '助動詞', '*', '*', '*', '特殊・タイ', '連用テ接続', 'たい', 'タク', 'タク'],
    ['なる', '動詞', '自立', '*', '*', '五段・ラ行', '基本形', 'なる', 'ナル', 'ナル'],
    ['な', '助詞', '終助詞', '*', '*', '*', '*', 'な', 'ナ', 'ナ']]
    """
    # exclude final two tokens : 'EOS', ''
    tokens = tagger.parse(text).split('\n')[:-2]
    tokens = [re.split(r'[,\t]', token) for token in tokens]
    surface, lemma, pos = [],[],[]
    for token in tokens:
        surface.append(token[0])
        lemma.append(token[7])
        pos.append(token[1])
    return surface, lemma, pos

# %%
l = tokenize('明日コロナにかかった')
l
# Out:
# (['明日', 'コロナ', 'に', 'かかっ', 'た'],
#  ['明日', 'コロナ', 'に', 'かかる', 'た'],
#  ['名詞', '名詞', '助詞', '動詞', '助動詞'])

# %%
len(pd.read_json('nhkweb2018.json'))

# %%
# concat json files
data = pd.read_json('nhkweb2012.json')
for i in range(2013,2020):
    data = pd.concat([data, pd.read_json(f'nhkweb{i}.json')])

# %%
data = data[['id','title','genre','article','datePublished']]
data
# Out:
#                     id                            title   genre  \
# 0      k10013902141000                    “原発政策ころころ変わる”    [政治]
# 1      k10014002951000                  六本木襲撃事件 １５人に逮捕状    [社会]
# 2      k10014085401000               専門家“ミサイル内部の機器不具合か”    [社会]
# 3      k10014344461000                    新華社“島巡る争いが試練”    [国際]
# 4      k10014441691000                   鉄板直撃２人死亡 会社を捜索    [社会]
# ...                ...                              ...     ...
# 42352  k10012232931000       日本ハム 斎藤佑樹投手が結婚 相手は同い年の一般女性  [スポーツ]
# 42353  k10012232941000  ＩＲ汚職 贈賄側は海外から1000万円超の現金 政界工作目的か    [社会]
# 42354  k10012232951000      西日本豪雨で被災 仮設住宅に年越しそば届ける 広島 呉    [社会]
# 42355  k10012232961000         ＷＢＯフライ級タイトルマッチ 田中が３回目の防衛  [スポーツ]
# 42356  k10012232971000        東京 渋谷 年越しカウントダウンで機動隊員らが警戒    [社会]
#
#                                                  article  \
# 0      野田総理大臣は、千葉県四街道市で街頭演説し、日本未来の党や日本維新の会が掲げる原子力政策につ...
# 1      ことし９月、東京・六本木のクラブで、客の男性が男らに金属バットのようなもので殴られて死亡した...
# 2      北朝鮮が発射を予告した事実上の弾道ミサイルを、１０日、発射しなかったことについて、海上自衛隊...
# 3      中国国営の新華社通信は、ことしの中国外交について、日本政府による沖縄県の尖閣諸島の国有化や南...
# 4      ２５日、広島県東広島市の国道を走っていた大型トレーラーの荷台から崩れ落ちた鉄板が乗用車を直撃...
# ...                                                  ...
# 42352  プロ野球・日本ハムは８年前のドラフト１位、31歳の斎藤佑樹投手が同い年の一般女性と結婚したこ...
# 42353  ＩＲ=統合型リゾート施設の事業をめぐって秋元司衆議院議員が逮捕された汚職事件で、贈賄側の中国...
# 42354  去年７月の西日本豪雨で大きな被害を受けた広島県呉市では大みそかの31日、ボランティア団体が仮...
# 42355  ボクシング、ＷＢＯ＝世界ボクシング機構のフライ級タイトルマッチが東京で行われ、チャンピオンの...
# 42356  令和最初の大みそかの31日、東京の渋谷駅周辺は年越しのカウントダウンで大勢の人で混雑する見込...
#
#                    datePublished
# 0               2012-12-02T18:09
# 1               2012-12-06T16:13
# 2               2012-12-10T15:51
# 3               2012-12-21T12:01
# 4               2012-12-26T13:49
# ...                          ...
# 42352  2019-12-31T17:27:02+09:00
# 42353  2019-12-31T17:53:01+09:00
# 42354  2019-12-31T19:05:20+09:00
# 42355  2019-12-31T19:09:07+09:00
# 42356  2019-12-31T19:26:54+09:00
#
# [97060 rows x 5 columns]

# %%
# make tokenized table
alllst = []
for line in data['article']:
    alllst.append(tokenize(line))

# %%
df = pd.DataFrame(alllst, columns=['tokens','lemma','pos'])
df
# Out:
#                                                   tokens  \
# 0      [野田, 総理, 大臣, は, 、, 千葉, 県, 四街道, 市, で, 街頭, 演説, し...
# 1      [ことし, ９月, 、, 東京, ・, 六本木, の, クラブ, で, 、, 客, の, 男...
# 2      [北朝鮮, が, 発射, を, 予告, し, た, 事実, 上, の, 弾道, ミサイル, ...
# 3      [中国, 国営, の, 新華社通信, は, 、, ことし, の, 中国, 外交, について,...
# 4      [２, ５, 日, 、, 広島, 県, 東広島, 市, の, 国道, を, 走っ, て, い...
# ...                                                  ...
# 97055  [プロ, 野球, ・, 日本ハム, は, ８, 年, 前, の, ドラフト, １, 位, 、...
# 97056  [ＩＲ, =, 統合, 型, リゾート, 施設, の, 事業, をめぐって, 秋元, 司, ...
# 97057  [去年, ７月, の, 西日本, 豪雨, で, 大きな, 被害, を, 受け, た, 広島,...
# 97058  [ボクシング, 、, ＷＢＯ, ＝, 世界, ボクシング, 機構, の, フライ, 級, タ...
# 97059  [令, 和, 最初, の, 大みそか, の, 31, 日, 、, 東京, の, 渋谷, 駅,...
#
#                                                    lemma  \
# 0      [野田, 総理, 大臣, は, 、, 千葉, 県, 四街道, 市, で, 街頭, 演説, す...
# 1      [ことし, ９月, 、, 東京, ・, 六本木, の, クラブ, で, 、, 客, の, 男...
# 2      [北朝鮮, が, 発射, を, 予告, する, た, 事実, 上, の, 弾道, ミサイル,...
# 3      [中国, 国営, の, 新華社通信, は, 、, ことし, の, 中国, 外交, について,...
# 4      [２, ５, 日, 、, 広島, 県, 東広島, 市, の, 国道, を, 走る, て, い...
# ...                                                  ...
# 97055  [プロ, 野球, ・, 日本ハム, は, ８, 年, 前, の, ドラフト, １, 位, 、...
# 97056  [ＩＲ, *, 統合, 型, リゾート, 施設, の, 事業, をめぐって, 秋元, 司, ...
# 97057  [去年, ７月, の, 西日本, 豪雨, で, 大きな, 被害, を, 受ける, た, 広島...
# 97058  [ボクシング, 、, ＷＢＯ, ＝, 世界, ボクシング, 機構, の, フライ, 級, タ...
# 97059  [令, 和, 最初, の, 大みそか, の, *, 日, 、, 東京, の, 渋谷, 駅, ...
#
#                                                      pos
# 0      [名詞, 名詞, 名詞, 助詞, 記号, 名詞, 名詞, 名詞, 名詞, 助詞, 名詞, 名...
# 1      [名詞, 名詞, 記号, 名詞, 記号, 名詞, 助詞, 名詞, 助詞, 記号, 名詞, 助...
# 2      [名詞, 助詞, 名詞, 助詞, 名詞, 動詞, 助動詞, 名詞, 名詞, 助詞, 名詞, ...
# 3      [名詞, 名詞, 助詞, 名詞, 助詞, 記号, 名詞, 助詞, 名詞, 名詞, 助詞, 記...
# 4      [名詞, 名詞, 名詞, 記号, 名詞, 名詞, 名詞, 名詞, 助詞, 名詞, 助詞, 動...
# ...                                                  ...
# 97055  [名詞, 名詞, 記号, 名詞, 助詞, 名詞, 名詞, 名詞, 助詞, 名詞, 名詞, 名...
# 97056  [名詞, 名詞, 名詞, 名詞, 名詞, 名詞, 助詞, 名詞, 助詞, 名詞, 名詞, 名...
# 97057  [名詞, 名詞, 助詞, 名詞, 名詞, 助詞, 連体詞, 名詞, 助詞, 動詞, 助動詞,...
# 97058  [名詞, 記号, 名詞, 記号, 名詞, 名詞, 名詞, 助詞, 名詞, 名詞, 名詞, 助...
# 97059  [名詞, 名詞, 名詞, 助詞, 名詞, 助詞, 名詞, 名詞, 記号, 名詞, 助詞, 名...
#
# [97060 rows x 3 columns]

# %%
# concat tables
data = pd.concat([data.reset_index(), df], axis=1)

# %%
data.iloc[:,1:].to_csv('nhkweb.csv', index=None)

# %% [markdown]
# # load csv

# %%
DATA = pd.read_csv('nhkweb.csv')

# %%
DATA
# Out:
#                     id                            title  \
# 0      k10013902141000                    “原発政策ころころ変わる”
# 1      k10014002951000                  六本木襲撃事件 １５人に逮捕状
# 2      k10014085401000               専門家“ミサイル内部の機器不具合か”
# 3      k10014344461000                    新華社“島巡る争いが試練”
# 4      k10014441691000                   鉄板直撃２人死亡 会社を捜索
# ...                ...                              ...
# 97055  k10012232931000       日本ハム 斎藤佑樹投手が結婚 相手は同い年の一般女性
# 97056  k10012232941000  ＩＲ汚職 贈賄側は海外から1000万円超の現金 政界工作目的か
# 97057  k10012232951000      西日本豪雨で被災 仮設住宅に年越しそば届ける 広島 呉
# 97058  k10012232961000         ＷＢＯフライ級タイトルマッチ 田中が３回目の防衛
# 97059  k10012232971000        東京 渋谷 年越しカウントダウンで機動隊員らが警戒
#
#                                                  article
# 0      野田総理大臣は、千葉県四街道市で街頭演説し、日本未来の党や日本維新の会が掲げる原子力政策につ...
# 1      ことし９月、東京・六本木のクラブで、客の男性が男らに金属バットのようなもので殴られて死亡した...
# 2      北朝鮮が発射を予告した事実上の弾道ミサイルを、１０日、発射しなかったことについて、海上自衛隊...
# 3      中国国営の新華社通信は、ことしの中国外交について、日本政府による沖縄県の尖閣諸島の国有化や南...
# 4      ２５日、広島県東広島市の国道を走っていた大型トレーラーの荷台から崩れ落ちた鉄板が乗用車を直撃...
# ...                                                  ...
# 97055  プロ野球・日本ハムは８年前のドラフト１位、31歳の斎藤佑樹投手が同い年の一般女性と結婚したこ...
# 97056  ＩＲ=統合型リゾート施設の事業をめぐって秋元司衆議院議員が逮捕された汚職事件で、贈賄側の中国...
# 97057  去年７月の西日本豪雨で大きな被害を受けた広島県呉市では大みそかの31日、ボランティア団体が仮...
# 97058  ボクシング、ＷＢＯ＝世界ボクシング機構のフライ級タイトルマッチが東京で行われ、チャンピオンの...
# 97059  令和最初の大みそかの31日、東京の渋谷駅周辺は年越しのカウントダウンで大勢の人で混雑する見込...
#
# [97060 rows x 3 columns]

# %%
genre = Counter()
for genres in DATA.genre:
    for g in eval(genres):
        genre[g] += 1
genre.most_common()
# Out:
# [('社会', 26837),
#  ('国際', 25302),
#  ('スポーツ', 14700),
#  ('政治', 13136),
#  ('ビジネス', 12473),
#  ('気象・災害', 9897),
#  ('科学・文化', 6470),
#  ('暮らし', 3677),
#  ('地域', 3093)]

# %%
pd.DataFrame(genre.most_common(), columns=['genre','count'])
# Out:
#    genre  count
# 0     社会  26837
# 1     国際  25302
# 2   スポーツ  14700
# 3     政治  13136
# 4   ビジネス  12473
# 5  気象・災害   9897
# 6  科学・文化   6470
# 7    暮らし   3677
# 8     地域   3093

# %%
# kango + する
KANJI = re.compile(r'[\u3400-\u4DBF\u4E00-\u9FFF\uF900-\uFAFF]{2,10}')
KATAKANA = re.compile(r'[ァ-ヶ]{1,2}')

def suru(genre=None, filename=None):
    count = Counter()
    df = {}
    if genre != None and type(genre) == str:
        genre = [genre]
    genre = set(genre)
    
    for i, row in DATA.iterrows():
        if not genre <= set(eval(row.genre)):
            continue
        lemmas = eval(row.lemma)
        for j, lemma in enumerate(lemmas):
            if j > 1 and lemma == 'する' and re.match(KANJI,lemmas[j-1]) and re.match(KANJI,lemmas[j-2]):
                word = ''.join(lemmas[j-2:j+1])
                count[word] += 1
                df[word] = df.get(word, []) + [i]
            elif j > 0 and lemma == 'する' and re.match(KANJI,lemmas[j-1]):
                word = ''.join(lemmas[j-1:j+1])
                count[word] += 1
                df[word] = df.get(word, []) + [i]
            
    return count, df

def katakana(genre=None):
    count = Counter()
    df = {}
    if genre != None and type(genre) == str:
        genre = [genre]
    genre = set(genre)
    
    for i, row in DATA.iterrows():
        if not genre <= set(eval(row.genre)):
            continue
        lemmas = eval(row.lemma)
        for j, lemma in enumerate(lemmas):
            if re.match(KATAKANA,lemma):
                count[lemma] += 1
                df[lemma] = df.get(lemma, []) + [i]
                
    return count, df

def get_df(total, word):
    return round(len(set(df[word])) / total * 100, 2)

# %% [markdown]
# # count

# %%
pd.DataFrame(genre.most_common(), columns=['genre','count'])
# Out:
#    genre  count
# 0     社会  26837
# 1     国際  25302
# 2   スポーツ  14700
# 3     政治  13136
# 4   ビジネス  12473
# 5  気象・災害   9897
# 6  科学・文化   6470
# 7    暮らし   3677
# 8     地域   3093

# %%
count, df = suru(genre='地域')
total = 3093

print(sum(count.values()))

for w,c in count.most_common(200):
    print(f'{w},{c},{get_df(total, w)}')
# Out:
# 18777
# 参加する,886,17.26
# 確認する,409,8.76
# 設置する,330,6.66
# 展示する,266,5.01
# 販売する,258,5.24
# 披露する,254,5.82
# 公開する,244,4.66
# 発表する,212,4.24
# 再開する,191,3.3
# 利用する,189,4.49
# 検討する,175,4.14
# 紹介する,163,3.85
# 撮影する,155,3.36
# 水揚げする,153,2.52
# 完成する,152,3.59
# 用意する,151,4.3
# 指定する,139,3.36
# 期待する,134,3.62
# 出席する,131,3.3
# 運行する,124,2.62
# 開発する,116,2.23
# 被災する,111,2.36
# 活用する,108,2.65
# 提供する,107,2.39
# 整備する,107,2.23
# 登録する,106,2.07
# 生息する,105,2.42
# 出発する,104,2.88
# 解除する,104,1.71
# 飼育する,103,2.33
# 説明する,100,2.88
# 発信する,100,2.46
# 導入する,99,1.88
# 出荷する,99,2.3
# 協力する,97,2.52
# 企画する,97,2.62
# 成長する,94,2.23
# 代表する,94,2.65
# 登場する,93,2.49
# 開催する,92,2.0
# 到着する,92,2.13
# 応援する,90,2.17
# 支援する,86,2.04
# 死亡する,84,1.78
# 栽培する,84,2.04
# 収穫する,83,1.94
# 制作する,82,1.84
# 感謝する,79,2.07
# 祈願する,77,1.84
# 再現する,77,1.71
# 感動する,75,2.1
# 注目する,74,1.81
# 管理する,73,1.97
# 避難する,71,1.58
# 記念する,71,1.78
# 体験する,69,1.55
# 表現する,69,1.88
# 獲得する,69,1.33
# 出場する,67,1.65
# 優勝する,66,1.36
# 発生する,65,1.71
# 挑戦する,64,1.78
# 担当する,63,1.65
# 逮捕する,63,0.91
# 主催する,62,1.84
# 予定する,62,1.84
# 誕生する,60,1.42
# 捕獲する,60,1.03
# 開花する,58,1.23
# 開通する,57,0.87
# 指摘する,56,1.33
# 観測する,56,1.13
# 保護する,55,1.16
# 運営する,54,1.49
# 保管する,54,1.13
# 開幕する,53,1.36
# 対応する,52,1.33
# 予想する,52,1.23
# 購入する,51,1.33
# 安心する,49,1.26
# 活躍する,48,1.36
# 認定する,48,0.87
# 見学する,47,1.23
# 移動する,47,1.2
# 解禁する,46,0.97
# 寄付する,45,0.94
# 確保する,45,1.13
# 運転する,45,0.74
# 建設する,44,1.1
# 貢献する,44,1.07
# 心配する,44,1.16
# 連携する,43,1.16
# 報告する,43,1.16
# 生産する,43,1.2
# 奉納する,42,0.94
# 復活する,42,0.91
# 訪問する,40,0.81
# 撤去する,37,0.65
# 活動する,37,0.94
# 作成する,37,0.78
# 判断する,36,1.03
# 提出する,36,0.74
# 開設する,35,0.91
# 強化する,35,0.84
# 成功する,35,0.91
# 営業する,35,0.91
# 引退する,35,0.74
# 製造する,35,0.84
# 合格する,35,0.58
# 投稿する,35,0.71
# 想定する,34,0.91
# 開業する,34,0.91
# 出品する,34,0.68
# 保存する,34,0.81
# 達成する,34,0.74
# 目撃する,34,0.78
# 分析する,34,0.91
# 実施する,34,0.87
# 解体する,33,0.78
# 回復する,33,0.87
# 閉鎖する,33,0.74
# 演奏する,33,0.74
# 再建する,32,0.78
# 受賞する,32,0.65
# 公表する,31,0.58
# 宣言する,31,0.61
# 評価する,31,0.91
# 出演する,31,0.84
# 調査する,30,0.87
# 継続する,30,0.74
# 中止する,30,0.58
# 終了する,30,0.68
# 実現する,30,0.94
# 廃止する,30,0.68
# 観察する,29,0.74
# 採用する,29,0.68
# 一般公開する,29,0.71
# 開放する,29,0.68
# 試食する,29,0.68
# 掲載する,29,0.71
# 減少する,28,0.78
# 規制する,28,0.58
# 復元する,28,0.55
# 隣接する,28,0.84
# 派遣する,28,0.61
# 衝突する,27,0.55
# 全壊する,27,0.68
# 懸念する,27,0.74
# 寄贈する,27,0.48
# 注意する,26,0.65
# 散策する,26,0.74
# 視察する,26,0.58
# 運航する,26,0.65
# 卒業する,26,0.71
# 勉強する,25,0.68
# 余儀ないする,25,0.68
# 参列する,25,0.55
# 安定する,25,0.61
# 後押しする,25,0.74
# 禁止する,25,0.58
# 更新する,25,0.58
# 把握する,25,0.65
# 献上する,25,0.26
# 激励する,24,0.61
# 記録する,24,0.65
# 落下する,24,0.45
# 経営する,24,0.71
# 浸水する,24,0.65
# 所有する,24,0.71
# 所属する,24,0.71
# 急増する,23,0.55
# 使用する,23,0.65
# 緊張する,23,0.71
# 維持する,23,0.58
# 立候補する,23,0.45
# 希望する,22,0.65
# 相談する,22,0.61
# 実感する,22,0.68
# 制限する,22,0.55
# 参拝する,22,0.58
# 検証する,22,0.48
# 募集する,22,0.58
# 配置する,22,0.58
# 復旧する,22,0.52
# 通過する,22,0.58
# 悪化する,21,0.48
# 上映する,21,0.36
# 回転する,21,0.45
# 発見する,21,0.58
# 帰省する,21,0.48
# 努力する,21,0.55
# 完了する,21,0.61
# 検出する,21,0.32
# 交流する,20,0.58
# 調整する,20,0.52
# 出店する,20,0.52
# 配布する,20,0.55
# 放送する,20,0.45
# 提案する,20,0.61
# 移住する,20,0.39

# %%
# Out:
# 36067535

# %%
DATA.loc[:1000][['id','title','article','datePublished']].to_json('nhksmall.json', force_ascii=False, orient='records', lines=True)

# %%
config = {'user': 'nozomi',
        'password': 'database',
        'host': 'chula.cd7wwaejjsg3.ap-southeast-1.rds.amazonaws.com',
        'database': 'jtdic'}


# connect & insert
cn = mysql.connector.connect(**config)
cursor = cn.cursor()

# %%
word = '男子中学生'
cursor.execute(f"SELECT DISTINCT title, article FROM nhksmall WHERE article LIKE '%{word}%'")
result = list(cursor) # [[title, article],,]
if result == []:
    reply = 'หาไม่เจอในคลังข้อมูลครับ\n(พิมพ์ help จะแสดงวิธีใช้)'
else:
    if len(result) > 5:
        result = random.sample(result, 5)
    reply = ''
    pattern = re.compile(f'(?:^|[、。])([^、。]*?{word}[^、。]*?(?:[、。]|$))')
    for title, article in result:
        candidates = re.findall(pattern, article)
        reply += '・' + random.choice(candidates) + '\n\n'
    reply = reply.strip()

# %%
re.findall(pattern, article)
# Out:
# ['川崎市の河川敷で男子中学生が殺害され、']

# %% [markdown]
# # export for SQL

# %%
DATA = DATA[['id','title','article']]
DATA['article'] = DATA['article'].apply(lambda x:re.sub(r'\n+','',x))

# %%
DATA.to_csv('nhkweb.csv',index=None)

# %%
# !wc -l nhkweb.csv
# Out:
#    97061 nhkweb.csv
